# %%
# !pip install gmaps

# %% [markdown]
# Read_metering_fraud_file

# %%
import json
import gmaps
import gmaps.datasets
import pandas as pd
import numpy as np

# %%
gmaps.configure(api_key='AIzaSyBqh7pfmacU3sWDqZPevAU-C43Q5xLwMTk')

# %%
N3_coordinates = (15.096720, 100.744234)
gmaps.figure(center=N3_coordinates, zoom_level=8)
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %% [markdown]
# create dataFrame Fraud data from temp_dict_fraud_detect.json

# %%
with open('temp_dict_fraud_detect.json') as json_file:  
    fraud_data = json.load(json_file)
list_cust_no=[]
list_year=[]
list_month=[]
list_feeder=[]
list_LATITUDE=[]
list_LONGITUDE=[]
for cust_no in list(fraud_data.keys()):
#     print(cust_no)
    for year in list(fraud_data[cust_no].keys()):
        for month in list(fraud_data[cust_no][year].keys()):
            list_cust_no.append(cust_no)
            list_year.append(year)
            list_month.append(month)
            list_feeder.append(fraud_data[cust_no][year][month]['Feeder_ID'])
            list_LATITUDE.append(fraud_data[cust_no][year][month]['LATITUDE'])
            list_LONGITUDE.append(fraud_data[cust_no][year][month]['LONGITUDE'])

# %%
df_fraud=pd.DataFrame()
df_fraud['cust_no']=list_cust_no
df_fraud['year']=list_year
df_fraud['month']=list_month
df_fraud['feeder_ID']=list_feeder
df_fraud['LATITUDE']=list_LATITUDE
df_fraud['LONGITUDE']=list_LONGITUDE

# %%
N3_coordinates = (15.096720, 100.744234)
figure_layout = {
'width': '800px',
'height': '800px',
'border': '1px solid black',
'padding': '1px'
}



fig = gmaps.figure(center=N3_coordinates, zoom_level=8, layout=figure_layout)
for year in ['2016', '2017', '2018', '2019']:
    temp_df=df_fraud.drop(list(np.where(df_fraud['year']!=year)[0])).copy()
    temp_df=temp_df.reset_index(drop=True)
    if year == '2016':
        color = 'rgba(0, 0, 100, 0.4)' #blue
    elif year == '2017':
        color = 'rgba(200, 0, 0, 0.4)' #Red
    elif year == '2018':
        color = 'rgba(200, 100, 0, 0.4)' #orange
    elif year == '2019':
        color = 'rgba(0, 100, 0, 0.4)'
    fraud_location=temp_df[['LATITUDE', 'LONGITUDE']]
    fraud_layer = gmaps.symbol_layer(
        fraud_location, fill_color=color, stroke_color=color, scale=3)
    fig.add_layer(fraud_layer)
fig
# Out:
# Figure(layout=FigureLayout(border='1px solid black', height='800px', padding='1px', width='800px'))

# %%
fraud_location=df_fraud[['LATITUDE', 'LONGITUDE']]

fraud_layer = gmaps.symbol_layer(
    fraud_location, fill_color="red", stroke_color="red", scale=2)

fig = gmaps.figure()
fig.add_layer(fraud_layer)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# Out:
# ---------------------------------------------------------------------------
# TraitError                                Traceback (most recent call last)
# C:\Users\ece\Desktop\Pornchai\Anaconda\envs\pornchai\lib\site-packages\traitlets\traitlets.py in validate_elements(self, obj, value)
#    2251             try:
# -> 2252                 v = self._trait._validate(obj, v)
#    2253             except TraitError:
#
# C:\Users\ece\Desktop\Pornchai\Anaconda\envs\pornchai\lib\site-packages\traitlets\traitlets.py in _validate(self, obj, value)
#     590         if hasattr(self, 'validate'):
# --> 591             value = self.validate(obj, value)
#     592         if obj._cross_validation_lock is False:
#
# C:\Users\ece\Desktop\Pornchai\Anaconda\envs\pornchai\lib\site-packages\traitlets\traitlets.py in validate(self, obj, value)
#    1676         else:
# -> 1677             self.error(obj, value)
#    1678
#
# C:\Users\ece\Desktop\Pornchai\Anaconda\envs\pornchai\lib\site-packages\traitlets\traitlets.py in error(self, obj, value)
#    1523
# -> 1524         raise TraitError(e)
#    1525
#
# TraitError: The 'None' trait of a Map instance must be a Widget, but a value of class 'pandas.core.frame.DataFrame' (i.e.       LATITUDE   LONGITUDE
# 0    14.801832  100.438342
# 1    15.324700  101.189804
# 2    15.766417  100.141484
# 3    15.185161  100.397542
# 4    15.052152  100.566940
# 5    15.735252  100.101821
# 6    15.670719  100.059152
# 7    15.670741  100.059064
# 8    15.670705  100.058994
# 9    15.670754  100.059098
# 10   15.670761  100.059059
# 11   16.110194  101.166213
# 12   15.985311  101.065665
# 13   15.073413  100.225212
# 14    0.000000    0.000000
# 15   16.425197  101.164621
# 16   15.725431  100.185318
# 17    0.000000    0.000000
# 18   14.947973   99.828784
# 19   14.948480   99.827950
# 20    0.000000    0.000000
# 21   15.716456  100.136294
# 22   15.808743  100.598167
# 23   15.808743  100.598167
# 24    0.000000    0.000000
# 25   14.997818   99.985330
# 26   15.677829  100.141539
# 27   15.677895  100.141554
# 28   15.678091  100.141590
# 29   15.677858  100.141579
# ..         ...         ...
# 213  15.845804  100.158820
# 214  15.770412  100.093557
# 215  15.702973  100.099849
# 216  15.575371  101.059982
# 217  15.834729  100.069524
# 218  15.956523  100.747670
# 219  15.955512  100.748215
# 220  15.956523  100.747670
# 221  15.956323  100.747665
# 222  15.721720  100.109105
# 223  15.789492  100.081719
# 224  14.804363  100.329277
# 225  15.802091  100.087874
# 226  15.926538  100.047020
# 227  15.921727  100.166357
# 228  15.807396  100.169235
# 229  15.810337  100.193264
# 230  15.902561  100.140476
# 231  15.842167  100.113856
# 232  15.910612  100.070920
# 233  15.834357  100.158988
# 234  15.847343  100.116308
# 235  16.708375  101.172416
# 236  15.829739  100.071116
# 237  15.157647  101.178797
# 238  15.910097  100.070838
# 239  15.910075  100.070737
# 240  15.938618  100.122543
# 241  15.830832  100.056306
# 242  15.840432  100.156942
#
# [243 rows x 2 columns]) was specified.
#
# During handling of the above exception, another exception occurred:
#
# TraitError                                Traceback (most recent call last)
# <ipython-input-42-a1ba6a0a1f9c> in <module>
#       1 fig = gmaps.figure()
# ----> 2 fig.add_layer(fraud_location)
#       3 fig
#
# C:\Users\ece\Desktop\Pornchai\Anaconda\envs\pornchai\lib\site-packages\gmaps\figure.py in add_layer(self, layer)
#     110         except AttributeError:
#     111             pass
# --> 112         self._map.add_layer(layer)
#     113
#     114
#
# C:\Users\ece\Desktop\Pornchai\Anaconda\envs\pornchai\lib\site-packages\gmaps\maps.py in add_layer(self, layer)
#     199
#     200     def add_layer(self, layer):
# --> 201         self.layers = tuple([l for l in self.layers] + [layer])
#     202
#     203     @default('layout')
#
# C:\Users\ece\Desktop\Pornchai\Anaconda\envs\pornchai\lib\site-packages\traitlets\traitlets.py in __set__(self, obj, value)
#     583             raise TraitError('The "%s" trait is read-only.' % self.name)
#     584         else:
# --> 585             self.set(obj, value)
#     586
#     587     def _validate(self, obj, value):
#
# C:\Users\ece\Desktop\Pornchai\Anaconda\envs\pornchai\lib\site-packages\traitlets\traitlets.py in set(self, obj, value)
#     557
#     558     def set(self, obj, value):
# --> 559         new_value = self._validate(obj, value)
#     560         try:
#     561             old_value = obj._trait_values[self.name]
#
# C:\Users\ece\Desktop\Pornchai\Anaconda\envs\pornchai\lib\site-packages\traitlets\traitlets.py in _validate(self, obj, value)
#     589             return value
#     590         if hasattr(self, 'validate'):
# --> 591             value = self.validate(obj, value)
#     592         if obj._cross_validation_lock is False:
#     593             value = self._cross_validate(obj, value)
#
# C:\Users\ece\Desktop\Pornchai\Anaconda\envs\pornchai\lib\site-packages\traitlets\traitlets.py in validate(self, obj, value)
#    2322
#    2323     def validate(self, obj, value):
# -> 2324         value = super(List, self).validate(obj, value)
#    2325         value = self.validate_elements(obj, value)
#    2326         return value
#
# C:\Users\ece\Desktop\Pornchai\Anaconda\envs\pornchai\lib\site-packages\traitlets\traitlets.py in validate(self, obj, value)
#    2240             return value
#    2241
# -> 2242         value = self.validate_elements(obj, value)
#    2243
#    2244         return value
#
# C:\Users\ece\Desktop\Pornchai\Anaconda\envs\pornchai\lib\site-packages\traitlets\traitlets.py in validate_elements(self, obj, value)
#    2319             self.length_error(obj, value)
#    2320
# -> 2321         return super(List, self).validate_elements(obj, value)
#    2322
#    2323     def validate(self, obj, value):
#
# C:\Users\ece\Desktop\Pornchai\Anaconda\envs\pornchai\lib\site-packages\traitlets\traitlets.py in validate_elements(self, obj, value)
#    2252                 v = self._trait._validate(obj, v)
#    2253             except TraitError:
# -> 2254                 self.element_error(obj, v, self._trait)
#    2255             else:
#    2256                 validated.append(v)
#
# C:\Users\ece\Desktop\Pornchai\Anaconda\envs\pornchai\lib\site-packages\traitlets\traitlets.py in element_error(self, obj, element, validator)
#    2231         e = "Element of the '%s' trait of %s instance must be %s, but a value of %s was specified." \
#    2232             % (self.name, class_of(obj), validator.info(), repr_type(element))
# -> 2233         raise TraitError(e)
#    2234
#    2235     def validate(self, obj, value):
#
# TraitError: Element of the 'layers' trait of a Map instance must be a Widget, but a value of       LATITUDE   LONGITUDE
# 0    14.801832  100.438342
# 1    15.324700  101.189804
# 2    15.766417  100.141484
# 3    15.185161  100.397542
# 4    15.052152  100.566940
# 5    15.735252  100.101821
# 6    15.670719  100.059152
# 7    15.670741  100.059064
# 8    15.670705  100.058994
# 9    15.670754  100.059098
# 10   15.670761  100.059059
# 11   16.110194  101.166213
# 12   15.985311  101.065665
# 13   15.073413  100.225212
# 14    0.000000    0.000000
# 15   16.425197  101.164621
# 16   15.725431  100.185318
# 17    0.000000    0.000000
# 18   14.947973   99.828784
# 19   14.948480   99.827950
# 20    0.000000    0.000000
# 21   15.716456  100.136294
# 22   15.808743  100.598167
# 23   15.808743  100.598167
# 24    0.000000    0.000000
# 25   14.997818   99.985330
# 26   15.677829  100.141539
# 27   15.677895  100.141554
# 28   15.678091  100.141590
# 29   15.677858  100.141579
# ..         ...         ...
# 213  15.845804  100.158820
# 214  15.770412  100.093557
# 215  15.702973  100.099849
# 216  15.575371  101.059982
# 217  15.834729  100.069524
# 218  15.956523  100.747670
# 219  15.955512  100.748215
# 220  15.956523  100.747670
# 221  15.956323  100.747665
# 222  15.721720  100.109105
# 223  15.789492  100.081719
# 224  14.804363  100.329277
# 225  15.802091  100.087874
# 226  15.926538  100.047020
# 227  15.921727  100.166357
# 228  15.807396  100.169235
# 229  15.810337  100.193264
# 230  15.902561  100.140476
# 231  15.842167  100.113856
# 232  15.910612  100.070920
# 233  15.834357  100.158988
# 234  15.847343  100.116308
# 235  16.708375  101.172416
# 236  15.829739  100.071116
# 237  15.157647  101.178797
# 238  15.910097  100.070838
# 239  15.910075  100.070737
# 240  15.938618  100.122543
# 241  15.830832  100.056306
# 242  15.840432  100.156942
#
# [243 rows x 2 columns] <class 'pandas.core.frame.DataFrame'> was specified.

# %%
df = gmaps.datasets.load_dataset_as_df('starbucks_kfc_uk')

starbucks_df = df[df['chain_name'] == 'starbucks']
starbucks_df = starbucks_df[['latitude', 'longitude']]

starbucks_layer = gmaps.symbol_layer(
    starbucks_df, fill_color="green", stroke_color="green", scale=2
)
fig = gmaps.figure()
fig.add_layer(starbucks_layer)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
starbucks_df
# Out:
#       latitude  longitude
# 0    57.143224  -2.111544
# 1    57.143568  -2.096921
# 2    57.132247  -2.123264
# 3    57.147790  -2.098023
# 4    50.842126  -0.251903
# 5    54.661554  -6.216257
# 6    54.721915  -6.221398
# 7    54.654844  -5.697606
# 8    54.449405  -6.389910
# 9    54.338576  -6.181319
# 10   51.149350   0.871216
# 11   51.143558   0.876705
# 12   52.022212   1.142230
# 13   51.655777  -0.202198
# 14   51.613809  -0.276451
# 15   51.571769  -0.196177
# 16   51.632337  -0.266371
# 17   51.590785   0.479527
# 18   51.569273   0.460750
# 19   51.265572  -1.085481
# 20   51.266452  -1.087614
# 21   51.380831  -2.363118
# 22   51.381912  -2.359463
# 23   52.136110  -0.478392
# 24   54.585029  -5.941012
# 25   54.587272  -5.932406
# 26   54.598614  -5.928349
# 27   54.599634  -5.927585
# 28   54.600620  -5.934267
# 29   54.580289  -5.965722
# ..         ...        ...
# 689  51.510277  -0.133889
# 690  51.494984  -0.144366
# 691  51.494984  -0.144366
# 692  51.510382  -0.127557
# 693  51.514629  -0.144735
# 694  51.517516  -0.177452
# 695  53.546312  -2.631397
# 696  53.552112  -2.665777
# 697  51.299282  -2.199649
# 698  51.063108  -1.779915
# 699  51.062349  -1.314389
# 700  51.522115  -0.722101
# 701  51.483778  -0.608778
# 702  53.433216  -3.065435
# 703  53.306006  -2.961513
# 704  53.349315  -2.985802
# 705  51.319336  -0.558767
# 706  51.318078  -0.557414
# 707  52.584689  -2.126855
# 708  52.193245  -2.221673
# 709  50.810987  -0.369644
# 710  50.828822  -0.375470
# 711  53.044525  -2.989094
# 712  51.629718  -0.755388
# 713  51.570306  -0.775595
# 714  53.959675  -1.084199
# 715  53.958304  -1.093038
# 716  53.922162  -1.077482
# 717  53.988593  -1.045283
# 718  53.961130  -1.082780
#
# [719 rows x 2 columns]
